# %%
import json
import os
import shutil
import pandas as pd
import numpy as np
import datetime
import glob
from tqdm import tqdm
import unidecode
import subprocess
import  tarfile
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET
import ast
import zipfile

# %% [markdown]
# # Le Figaro

# %% [markdown]
# ## Processing the data

# %%
json_files = glob.glob('/scratch/students/bousbina/corpus/France/le_figaro/**/*.json', recursive=True)

# Count the number of files, which represents the number of articles
num_articles = len(json_files)

print("Total number of articles:", num_articles)
# Out:
# Total number of articles: 28503

# %%
os.makedirs('/scratch/students/bousbina/corpus/France/filtered_files_president', exist_ok=True)

     
                    
# Traverse all JSON files
json_count = 0
filter_count = 0
for root, dirs, files in os.walk('/scratch/students/bousbina/corpus/France/le_figaro'):
    for file_name in files:
        if file_name.endswith('.json'):
            with open(os.path.join(root, file_name)) as json_file:
                json_text = json.load(json_file)
                json_count += 1
                if "président" in json.dumps(json_text):
            # Copy file in filtered file directoy
                    shutil.copyfile(os.path.join(root, file_name), os.path.join('/scratch/students/bousbina/corpus/France/filtered_files_president', file_name))
                    filter_count += 1
                    print(filter_count)

# %%
print(f"Found {json_count} JSON files in the directory")
dir_path = '/scratch/students/bousbina/corpus/France/filtered_files_president'
count = 0
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1

print(f"Found  {count} JSON filtered files according to the word president")
# Out:
# Found 28503 JSON files in the directory
# Found  855 JSON filtered files according to the word president

# %% [markdown]
# ## Counting the number and the length of articles

# %%
if not os.path.exists("/scratch/students/bousbina/corpus/France/data"):
    os.makedirs("/scratch/students/bousbina/corpus/France/data")

# Get list of all articles
every_article = glob.glob('/scratch/students/bousbina/corpus/France/filtered_files_president/*.json')
president_articles = pd.DataFrame(columns=["publication_date", "content"])
dates_fr = set()


for article in tqdm(every_article):
    date = article.split("/")[-1][:10]
    dates_fr.add(date)
    with open(article, 'r') as f:
        data = json.load(f)   
        if any(x in unidecode.unidecode(str.lower(data["contentAsText"][0])) for x in ('président')):
            # Increment counters and append data to dataframe
            president_articles.loc[date] = {"publication_date" : date, "content": data["contentAsText"][0]}

#Sort the dataframe by publication dates            
president_articles.sort_values(by=["publication_date"], inplace=True)

# Save data
president_articles.to_csv("/scratch/students/bousbina/corpus/France/data/president_articles_fr.csv")

# Save dates
with open('/scratch/students/bousbina/corpus/France/data/dates_fr.txt', 'w') as f:
    # parse dates as datetime objects and sort them
    dates_fr_sorted = sorted([datetime.datetime.strptime(date, '%Y%m%d.m') for date in dates_fr])
    # convert datetime objects back to strings in the desired format and write them to file
    f.write('\n'.join([date.strftime('%Y%m%d.m') for date in dates_fr_sorted]))
# Out:
# 100%|██████████████████████████████████████████████████████████████| 855/855 [00:11<00:00, 73.60it/s]

# %% [markdown]
# ## Counting raw "président" frequency in the corpus

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/scratch/students/bousbina/corpus/France/data/president_articles_fr.csv")
df = df.sort_values(by="publication_date")

# Convert the name of the column "publication_date" from string to date format
df["publication_date"] = pd.to_datetime(df["publication_date"], format="%Y%m%d.m").dt.date

# Set index to publication_date column
df = df.set_index("publication_date")

# We define a function that counts raw frequency
def count_word_frequency(word, text):
    return text.count(word)

# Create a new column in the dataframe for the raw frequency of the word in each row using the apply() method and the count_word_frequency() function.
word = "president"
df["frequency"] = df["content"].apply(lambda x: count_word_frequency(word, x))

# Fit a polynomial regression to the raw frequency data using numpy.polyfit() and numpy.polyval().
x = np.arange(len(df.index))
y = df["frequency"]
degree = 10  # Change the degree of the polynomial regression here
coeffs = np.polyfit(x, y, degree)
frequencies_polyfit = np.polyval(coeffs, x)

# Plot the raw frequencies and the polynomial fit using Matplotlib.
plt.figure(figsize=(10, 7))
plt.plot(df.index, df["frequency"], label="Raw frequencies")
plt.plot(df.index, frequencies_polyfit, label=f"Polynomial fit (degree={degree})")
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Fit a linear regression model to the data
model = LinearRegression()
X = np.arange(len(df)).reshape(-1, 1)
y = df['frequency'].values.reshape(-1, 1)
model.fit(X, y)

# Add a regression line to the scatter plot
plt.plot(df.index, model.predict(X), label="Linear regression")
plt.legend()
plt.show()

# %% [markdown]
# ## Observation of the trigram "le président" in four different blocks:
# ### [1840-1860] ,[1860-1880], [1880-1900], [1900-1920]

# %%
import nltk 
import datetime
nltk.download('punkt')
from nltk import ngrams
from nltk.text import Text
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
from nltk.collocations import BigramAssocMeasures, TrigramAssocMeasures
from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder
# Out:
# [nltk_data] Downloading package punkt to /home/bousbina/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### Dividing the dates into four blocks

# %%
# Load the CSV file into a pandas data frame
pd.options.mode.chained_assignment = None  # default='warn'
df = pd.read_csv("/scratch/students/bousbina/corpus/France/data/president_articles_fr.csv")

df['publication_date'] = pd.to_datetime(df['publication_date'], format='%Y%m%d.m').dt.date

# Define the date ranges
range1 = (datetime.datetime.strptime('18400101.m', '%Y%m%d.m').date(),
          datetime.datetime.strptime('18601231.m', '%Y%m%d.m').date())

range2 = (datetime.datetime.strptime('18600101.m', '%Y%m%d.m').date(),
          datetime.datetime.strptime('18801231.m', '%Y%m%d.m').date())

range3 = (datetime.datetime.strptime('18800101.m', '%Y%m%d.m').date(),
          datetime.datetime.strptime('19001231.m', '%Y%m%d.m').date())

range4 = (datetime.datetime.strptime('19000101.m', '%Y%m%d.m').date(),
          datetime.datetime.strptime('19201231.m', '%Y%m%d.m').date())

# Open the file and read the dates
with open('/scratch/students/bousbina/corpus/France/data/dates_fr.txt', 'r') as f:
    dates = f.read().splitlines()

# Convert the dates to date objects
dates = [datetime.datetime.strptime(date, '%Y%m%d.m').date() for date in dates]

block1 = df.loc[df["publication_date"].isin(dates) & df["publication_date"].between(range1[0], range1[1])]
new_value1 = block1["content"].apply(nltk.word_tokenize) 
block1.loc[:, "tokens"] =  new_value1

block2 = df.loc[df["publication_date"].isin(dates) & df["publication_date"].between(range2[0], range2[1])]
new_value2 = block2["content"].apply(nltk.word_tokenize) 
block2.loc[:, "tokens"] =  new_value2

block3 = df.loc[df["publication_date"].isin(dates) & df["publication_date"].between(range3[0], range3[1])]
new_value3 = block3["content"].apply(nltk.word_tokenize) 
block3.loc[:, "tokens"] =  new_value3

block4 = df.loc[df["publication_date"].isin(dates) & df["publication_date"].between(range4[0], range4[1])]
new_value4 = block4["content"].apply(nltk.word_tokenize) 
block4.loc[:, "tokens"] =  new_value4

# Print the number of dates in each block
print(f"Block 1 ({range1[0]} - {range1[1]}): {len(block1)} dates")
print(f"Block 2 ({range2[0]} - {range2[1]}): {len(block2)} dates")
print(f"Block 3 ({range3[0]} - {range3[1]}): {len(block3)} dates")
print(f"Block 4 ({range4[0]} - {range4[1]}): {len(block4)} dates")
# Out:
# Block 1 (1840-01-01 - 1860-12-31): 0 dates
# Block 2 (1860-01-01 - 1880-12-31): 53 dates
# Block 3 (1880-01-01 - 1900-12-31): 34 dates
# Block 4 (1900-01-01 - 1920-12-31): 178 dates

# %%
import pandas as pd
from nltk import FreqDist



# Create a list of tri-grams in the tokenized text for each block
tri_grams_block_1 = [tri for doc in block1["tokens"] for tri in nltk.ngrams(doc, 3) if (("Le", "président", "est") == tri) ]
tri_grams_block_2 = [tri for doc in block2["tokens"] for tri in nltk.ngrams(doc, 3) if (("Le", "président", "est") == tri) ]
tri_grams_block_3 = [tri for doc in block3["tokens"] for tri in nltk.ngrams(doc, 3) if (("Le", "président", "est") == tri) ]
tri_grams_block_4 = [tri for doc in block4["tokens"] for tri in nltk.ngrams(doc, 3) if (("Le", "président", "est") == tri) ]

# Compute the frequency distribution of the tri-grams for each block
freq_dist_block_1 = FreqDist(tri_grams_block_1)
freq_dist_block_2 = FreqDist(tri_grams_block_2)
freq_dist_block_3 = FreqDist(tri_grams_block_3)
freq_dist_block_4 = FreqDist(tri_grams_block_4)

#Print all occurrences of the tri-gram "le président est" in each block of tokenized text,
print("Block 1 (1840-1860):")
print(tri_grams_block_1)
print("Block 2 (1860-1880):")
print(tri_grams_block_2)
print("Block 3 (1880-1900):")
print(tri_grams_block_3)
print("Block 4 (1900-1920):")
print(tri_grams_block_4)


#find the adjectifve after le président est
# Out:
# Block 1 (1840-1860):
# []
# Block 2 (1860-1880):
# []
# Block 3 (1880-1900):
# []
# Block 4 (1900-1920):
# []

# %% [markdown]
# ### Most common occurences in the blocks

# %%
# Print the five most common word uses of the tri-gram "le président est" in each block
print("Block 1 (1840-1860):")
print(freq_dist_block_1.most_common(5))
print("Block 2 (1860-1880):")
print(freq_dist_block_2.most_common(5))
print("Block 3 (1880-1900):")
print(freq_dist_block_3.most_common(5))
print("Block 4 (1900-1920):")
print(freq_dist_block_4.most_common(5))
# Out:
# Block 1 (1840-1860):
# []
# Block 2 (1860-1880):
# []
# Block 3 (1880-1900):
# []
# Block 4 (1900-1920):
# []

# %% [markdown]
# ### Occurences of  the two grams before and after “ président  ”

# %%
import re
import spacy
import string 
import pandas as pd
from nltk import FreqDist

# %%
# Create a list of two-grams in the tokenized text for block 1
two_grams_block_1_before = []
two_grams_block_1_after = []

punctuations = string.punctuation



for doc in block1["tokens"]:
    doc = [word for word in doc if word not in punctuations and not word.isdigit()]
    for i in range(len(doc)):
        if doc[i] == ("président"):
            if i > 1:
                two_grams_block_1_before.append((doc[i-2], doc[i-1]))
            if i < len(doc)-3:
                two_grams_block_1_after.append((doc[i+1], doc[i+2]))




# Compute the frequency distribution of the tri-grams for block 1
freq_dist_block_1_before = FreqDist(two_grams_block_1_before)
freq_dist_block_1_after = FreqDist(two_grams_block_1_after)


with open("two-grams-output_president.txt", "w") as file:
    # Write the two-grams before "président"
    file.write("-------------------------BLOCK_1-----------------------Two-grams before 'le président':\n")
    for two_gram in two_grams_block_1_before:
        file.write(f"{two_gram[0]} {two_gram[1]}\n")
    # Write the two-grams after "président"
    file.write("-------------------------BLOCK_1-----------------------Two-grams after 'le président':\n")
    for two_gram in two_grams_block_1_after:
        file.write(f"{two_gram[0]} {two_gram[1]}\n")

# Print all occurrences of the tri-gram "le président" in block of tokenized text
print("Block 1 (1840-1860): \n")
print(f"2-grams before 'le président': \n")
print(two_grams_block_1_before, "\n")
print(f"2-grams after 'le président': \n")
print(two_grams_block_1_after, "\n")
print("Most common 2-grams before: \n")
print(freq_dist_block_1_before.most_common(), "\n")
print("Most common 2-grams after: \n")
print(freq_dist_block_1_after.most_common())
# Out:
# Block 1 (1840-1860):
#
# 2-grams before 'le président':
#
# []
#
# 2-grams after 'le président':
#
# []
#
# Most common 2-grams before:
#
# []
#
# Most common 2-grams after:
#
# []

# %%
# Create a list of two-grams in the tokenized text for block 2
two_grams_block_2_before = []
two_grams_block_2_after = []





for doc in block2["tokens"]:
    doc = [word for word in doc if word not in punctuations and not word.isdigit()]
    for i in range(len(doc)):
        if doc[i] == ("président"):
            if i > 1:
                two_grams_block_2_before.append((doc[i-2], doc[i-1]))
            if i < len(doc)-3:
                two_grams_block_2_after.append((doc[i+1], doc[i+2]))




# Compute the frequency distribution of the tri-grams for block 1
freq_dist_block_2_before = FreqDist(two_grams_block_2_before)
freq_dist_block_2_after = FreqDist(two_grams_block_2_after)



with open("two-grams-output_president.txt", "a") as file:
    # Write the two-grams before "président"
    file.write("-------------------------BLOCK_2-----------------------Two-grams before 'président':\n")
    for two_gram in two_grams_block_2_before:
        file.write(f"{two_gram[0]} {two_gram[1]}\n")
    # Write the two-grams after "président"
    file.write("-------------------------BLOCK_2-----------------------Two-grams after 'président':\n")
    for two_gram in two_grams_block_2_after:
        file.write(f"{two_gram[0]} {two_gram[1]}\n")


# Print all occurrences of the tri-gram "président" in block of tokenized text
print("Block 2 (1860-1880): \n")
print(f"2-grams before 'le président': \n")
print(two_grams_block_2_before, "\n")
print(f"2-grams after 'le président': \n")
print(two_grams_block_2_after, "\n")
print("Most common 2-grams before: \n")
print(freq_dist_block_2_before.most_common(), "\n")
print("Most common 2-grams after: \n")
print(freq_dist_block_2_after.most_common())
# Out:
# Block 2 (1860-1880):
#
# 2-grams before 'le président':
#
# [('M.', 'le'), ('M.', 'le'), ('Florence', 'le'), ('ans', 'le'), ('Scélérat', 'le'), ('Oui', 'le'), ('»', 'le'), ('de', "l'Ijnsfitut"), ('Saint-Roch', 'et'), ('«', 'Le'), ('m.', 'le'), ('m.', 'le'), ('si', 'le'), ('m.', 'le'), ('H.', 'le'), ('Eu', 'le'), ('u.', 'le'), ('M.', 'le'), ('M.', 'le'), ('m.', 'le'), ('bi', 'le'), ('si', 'le'), ('si', 'IM'), ('est', 'le'), ("l'arrivée", 'du'), ('1e', "''"), ('voter.', 'le'), ('m', 'le'), ('saucisson', 'le'), ('élection', 'le'), ('soncomble', 'le'), ('soir', 'le'), ('fort', 'le'), ('î', 'lè'), ('I', 'le'), ("L'hôtel", 'du'), ('dit', 'le'), ('M.', 'le'), ('monsieur', 'le'), ('sieur', 'le'), ('M.', 'le'), ('connu', 'du'), ('M.', 'le'), ('mie', 'qui'), ('larité', 'du'), ('glie', 'est'), ('mais', 'iô'), ("d'Au-", 'male'), ('mai', 'le'), ('M.', 'Javal'), ('dit', 'au'), ('par', 'le'), ('que', 'le'), ('M.', 'le'), ("''", 'le'), ('M.', 'le'), ('M.', 'le'), ('M.', 'le'), ('M.', 'le'), ('M.', 'le'), ('M.', 'le'), ('M.', 'le'), ('M.', 'le'), ('Mais', "l'ancien"), ('avec', 'le'), ('ou', 'territoriale'), ('celle', 'du'), ('interrogé', 'au'), ('M.', 'le'), ('un', 'nouveau'), ('envers', 'le'), ('``', 'Le'), ("d'imprimés", "L'ancien"), ('le', 'premier'), ('Ma', 'réchal'), ('du', 'Maréchal'), ('fauteuil', 'du'), ('Maréchal', 'Le'), ('cien', 'ministre'), ('par', 'le'), ('pas', 'le'), ('générali', "L'ancien"), ('prononce', 'le'), ('surtout', 'notre'), ('épuisé', 'Le'), ('et', 'le'), ('la', 'nouveau'), ('dè', "l'ancien"), ('de', 'Mornay'), ('ans', "l'honorable"), ('Le', 'maréchal'), ('décret', 'du'), ('M.', 'le'), ('de', 'son'), ('notre', 'honorable'), ('parole', "d'un"), ('Code', 'Le'), ('blond-roux', 'Le'), ('thousiasme', 'Le'), ('dit', 'le'), ('dit', 'le'), ('magistrat', 'éminent'), ('ans', 'Le'), ('paroles', 'du'), ("d'Au-", 'diffret-Pasquier'), ("l'Ely", 'sée'), ("l'in", 'fortuné'), ('...', 'le'), ('gauche', 'Bertauld'), ('assis', 'le'), ('commencer', 'Le'), ('dit', 'Le'), ('que', 'ce'), ('toujours', 'élire'), ("qu'aura", 'le'), ('discours', 'du'), ('charge.', 'le'), ('Oui', 'le'), ('prêts', 'le'), ('délivrés', 'le'), ('balsamo', 'le'), ('»', 'le'), ('...', 'le'), ("d'adresser", 'au'), ('Abel', 'Rognât'), ('observations', 'du'), ('démission', 'au'), ('remise', 'au'), ('effet', 'au'), ('Chambre', 'Le'), ('est', 'le'), ('M.', 'le'), ('responsabilité', 'comme'), ('deuxième', 'vice-'), ('troisième', 'vice-'), ('démenti', 'Le'), ('M.', 'Ducrey'), ('que', 'le'), ('distinguée', 'Le'), ('Chesnelong', 'sénateur'), ('adressée', 'au'), ('été', 'nommé'), ('février', 'le'), ('SI.-', 'le'), ('M.', 'le'), ('SI', 'le'), ('M.', 'le'), ('M.', 'le'), ("d'orçlinaire", 'le'), ("aujourd'hui", 'le'), ('SI', 'le'), ('SI', 'le'), ('M.', 'le'), ('BS', 'le'), ('M.', 'le'), ('RI', 'le'), ('SI', 'le'), ('SI', 'le'), ('que', 'le'), ('M-', 'le'), ('M.', 'le'), ('à', 'notre'), ('interpelle', 'le'), ('Nast', 'vice-'), ('nations', 'de'), ('choisi', 'comme'), ('Gambetta', 'restera'), ('M.', 'le'), ('Cernes-', 'son'), ('M.', 'Ballot')]
#
# 2-grams after 'le président':
#
# [('du', 'saint-'), ('procède', 'à'), ('Dis', 'Ion'), ('Ton', 'état'), ('Ne', 'professes-tu'), ("D'après", 'quels'), ('montrant', 'un'), ('Berlioz', 'de'), ('de', 'la'), ('et', 'les'), ('schneider', 'La'), ('sçhneidçb', 'Si'), ('S', 'chneider'), ('schneider', 'Né'), ('schneider', 'Arrivez'), ('de', 'la'), ('schneider', 'Si'), ('car', 'si'), ('la', 'juge'), ('schneider', 'Monsieur'), ('S', 'chneider'), ('S', 'chneider'), ('S', 'chneider'), ('dans', 'lequel'), ('flanqué', 'de'), ('impétueusement', '—'), ('—', 'Comment'), ('—', 'Citoyensj'), ('—', 'Me'), ('—', 'Citoyens.'), ('—', 'Nous'), ('—', 'Le'), ('désespéré', '—'), ('ému', '—'), ('—r', 'Citoyens'), ('du', 'conseil'), ('au', 'sein/de'), ('quand', 'un'), ('car', 'peut-être'), ("qu'en", 'agissant'), ('a', 'député'), ('de', '1a'), ('de', 'la'), ('à', 'tous'), ('de', 'la'), ('Il', 'lui'), ('explique', "qu'on"), ('de', 'cette'), ('de', 'la'), ('du', 'Conseil'), ('Monsieur', 'Dupin'), ('décidé', 'de'), ("s'efforça", 'vainement'), ("N'interrompez", 'pas'), ('M.', 'le'), ('Vous', "n'entendez"), ("J'appelle", 'de'), ('—', "C'est"), ('«', 'M.'), ('—', "J'ai"), ('...', 'De'), ('—', "L'armée"), ('—', 'Je'), ('de', 'la'), ('de', 'la'), ('puis', 'un'), ('est', 'prépondérante'), ('qui', 'l'), ('du', 'Conseil'), ('tous', 'les'), ('de', 'la'), ('Signé', 'duc'), ("l'avait", 'fait'), ('—', 'Voyons'), ('do', 'la'), ('ae', 'la'), ('La', 'salle'), ('et', 'M.'), ('Bertrand', 'mem'), ('du', 'Conseil'), ('du', 'Conseil'), ('a', 'dû'), ('d', "'une"), ("d'âge", 'En'), ('a', 'fait'), ('de', 'la'), ('après', "qu'il"), ('Je', 'lui'), ('de', 'la'), ('a', 'donné'), ('après', 'son'), ('de', 'la'), ('de', 'la'), ('Une', 'grande'), ('a', 'été'), ('On', 'venait'), ('le', 'salua'), ('lit', "l'extrait"), ('dit', '«'), ("c'est", 'peut-'), ('vingt-deux', 'fois'), ("d'assi", 'ses'), ('stigmatise', 'le'), ('La', 'pauvre'), ('du', 'Sénat'), ('de', 'la'), ('lui', 'a'), ('de', 'la'), ('Calmon', 'Gilnert-Boucher'), ('le', 'préfet'), ("d'âge", 'monte'), ("d'âge", 'fait'), ("d'âge", 'est'), ('cet', 'homme'), ('etc', 'Aussi'), ('est', 'court'), ('Alors', 'vous'), ('balsamo', 'Quel'), ('Et', 'cependant'), ('Est-ce', 'vrai'), ('Je', 'le'), ('Parlez', 'maître'), ('BalSCtVM', 'r'), ('de', 'la'), ('du', 'cer'), ('Il', 'quitte'), ('de', 'cette'), ('de', 'la'), ('une', 'démission'), ('a', 'dû'), ('a', 'résolu'), ('ajouta', 'Mont'), ('du', 'Conseil'), ('»', 'Alors'), ('pour', 'que'), ('Grévy', "s'est"), ('de', 'la'), ('de', 'la'), ('du', 'comité'), ('A.', 'Baudon'), ('du', 'Comité'), ("d'honneur", 'Ces'), ('déclare', 'que'), ('Aux', 'termes'), ('res', 'pectueusement'), ('M.', 'Fresneau'), ('et', 'moi'), ('qui', 'est'), ('du', 'Sénat'), ('de', "l'Assemblée"), ('La', 'proposition'), ('Je', 'vous'), ('Je', 'ne'), ('Monsieur', 'do'), ('Vous', "n'avez"), ('Je', 'dois'), ("L'Assemblée", 'a'), ('..', 'Je'), ("s'adresse", 'pour'), ('Je-supplie', "l'Assembléa"), ('Je', 'vous'), ('pour', 'nous'), ('i', '«'), ('etc.', 'etc'), ('des', 'vice-prési'), ('pour', "l'année"), ('de', 'la'), ('du', 'Conseil'), ('du', 'Conseil'), ('de', 'section')]
#
# Most common 2-grams before:
#
# [(('M.', 'le'), 26), (('SI', 'le'), 5), (('m.', 'le'), 4), (('dit', 'le'), 3), (('que', 'le'), 3), (('Oui', 'le'), 2), (('»', 'le'), 2), (('si', 'le'), 2), (('est', 'le'), 2), (('par', 'le'), 2), (('...', 'le'), 2), (('Florence', 'le'), 1), (('ans', 'le'), 1), (('Scélérat', 'le'), 1), (('de', "l'Ijnsfitut"), 1), (('Saint-Roch', 'et'), 1), (('«', 'Le'), 1), (('H.', 'le'), 1), (('Eu', 'le'), 1), (('u.', 'le'), 1), (('bi', 'le'), 1), (('si', 'IM'), 1), (("l'arrivée", 'du'), 1), (('1e', "''"), 1), (('voter.', 'le'), 1), (('m', 'le'), 1), (('saucisson', 'le'), 1), (('élection', 'le'), 1), (('soncomble', 'le'), 1), (('soir', 'le'), 1), (('fort', 'le'), 1), (('î', 'lè'), 1), (('I', 'le'), 1), (("L'hôtel", 'du'), 1), (('monsieur', 'le'), 1), (('sieur', 'le'), 1), (('connu', 'du'), 1), (('mie', 'qui'), 1), (('larité', 'du'), 1), (('glie', 'est'), 1), (('mais', 'iô'), 1), (("d'Au-", 'male'), 1), (('mai', 'le'), 1), (('M.', 'Javal'), 1), (('dit', 'au'), 1), (("''", 'le'), 1), (('Mais', "l'ancien"), 1), (('avec', 'le'), 1), (('ou', 'territoriale'), 1), (('celle', 'du'), 1), (('interrogé', 'au'), 1), (('un', 'nouveau'), 1), (('envers', 'le'), 1), (('``', 'Le'), 1), (("d'imprimés", "L'ancien"), 1), (('le', 'premier'), 1), (('Ma', 'réchal'), 1), (('du', 'Maréchal'), 1), (('fauteuil', 'du'), 1), (('Maréchal', 'Le'), 1), (('cien', 'ministre'), 1), (('pas', 'le'), 1), (('générali', "L'ancien"), 1), (('prononce', 'le'), 1), (('surtout', 'notre'), 1), (('épuisé', 'Le'), 1), (('et', 'le'), 1), (('la', 'nouveau'), 1), (('dè', "l'ancien"), 1), (('de', 'Mornay'), 1), (('ans', "l'honorable"), 1), (('Le', 'maréchal'), 1), (('décret', 'du'), 1), (('de', 'son'), 1), (('notre', 'honorable'), 1), (('parole', "d'un"), 1), (('Code', 'Le'), 1), (('blond-roux', 'Le'), 1), (('thousiasme', 'Le'), 1), (('magistrat', 'éminent'), 1), (('ans', 'Le'), 1), (('paroles', 'du'), 1), (("d'Au-", 'diffret-Pasquier'), 1), (("l'Ely", 'sée'), 1), (("l'in", 'fortuné'), 1), (('gauche', 'Bertauld'), 1), (('assis', 'le'), 1), (('commencer', 'Le'), 1), (('dit', 'Le'), 1), (('que', 'ce'), 1), (('toujours', 'élire'), 1), (("qu'aura", 'le'), 1), (('discours', 'du'), 1), (('charge.', 'le'), 1), (('prêts', 'le'), 1), (('délivrés', 'le'), 1), (('balsamo', 'le'), 1), (("d'adresser", 'au'), 1), (('Abel', 'Rognât'), 1), (('observations', 'du'), 1), (('démission', 'au'), 1), (('remise', 'au'), 1), (('effet', 'au'), 1), (('Chambre', 'Le'), 1), (('responsabilité', 'comme'), 1), (('deuxième', 'vice-'), 1), (('troisième', 'vice-'), 1), (('démenti', 'Le'), 1), (('M.', 'Ducrey'), 1), (('distinguée', 'Le'), 1), (('Chesnelong', 'sénateur'), 1), (('adressée', 'au'), 1), (('été', 'nommé'), 1), (('février', 'le'), 1), (('SI.-', 'le'), 1), (("d'orçlinaire", 'le'), 1), (("aujourd'hui", 'le'), 1), (('BS', 'le'), 1), (('RI', 'le'), 1), (('M-', 'le'), 1), (('à', 'notre'), 1), (('interpelle', 'le'), 1), (('Nast', 'vice-'), 1), (('nations', 'de'), 1), (('choisi', 'comme'), 1), (('Gambetta', 'restera'), 1), (('Cernes-', 'son'), 1), (('M.', 'Ballot'), 1)]
#
# Most common 2-grams after:
#
# [(('de', 'la'), 19), (('du', 'Conseil'), 7), (('S', 'chneider'), 4), (('de', 'cette'), 2), (('a', 'dû'), 2), (('du', 'Sénat'), 2), (('Je', 'vous'), 2), (('du', 'saint-'), 1), (('procède', 'à'), 1), (('Dis', 'Ion'), 1), (('Ton', 'état'), 1), (('Ne', 'professes-tu'), 1), (("D'après", 'quels'), 1), (('montrant', 'un'), 1), (('Berlioz', 'de'), 1), (('et', 'les'), 1), (('schneider', 'La'), 1), (('sçhneidçb', 'Si'), 1), (('schneider', 'Né'), 1), (('schneider', 'Arrivez'), 1), (('schneider', 'Si'), 1), (('car', 'si'), 1), (('la', 'juge'), 1), (('schneider', 'Monsieur'), 1), (('dans', 'lequel'), 1), (('flanqué', 'de'), 1), (('impétueusement', '—'), 1), (('—', 'Comment'), 1), (('—', 'Citoyensj'), 1), (('—', 'Me'), 1), (('—', 'Citoyens.'), 1), (('—', 'Nous'), 1), (('—', 'Le'), 1), (('désespéré', '—'), 1), (('ému', '—'), 1), (('—r', 'Citoyens'), 1), (('du', 'conseil'), 1), (('au', 'sein/de'), 1), (('quand', 'un'), 1), (('car', 'peut-être'), 1), (("qu'en", 'agissant'), 1), (('a', 'député'), 1), (('de', '1a'), 1), (('à', 'tous'), 1), (('Il', 'lui'), 1), (('explique', "qu'on"), 1), (('Monsieur', 'Dupin'), 1), (('décidé', 'de'), 1), (("s'efforça", 'vainement'), 1), (("N'interrompez", 'pas'), 1), (('M.', 'le'), 1), (('Vous', "n'entendez"), 1), (("J'appelle", 'de'), 1), (('—', "C'est"), 1), (('«', 'M.'), 1), (('—', "J'ai"), 1), (('...', 'De'), 1), (('—', "L'armée"), 1), (('—', 'Je'), 1), (('puis', 'un'), 1), (('est', 'prépondérante'), 1), (('qui', 'l'), 1), (('tous', 'les'), 1), (('Signé', 'duc'), 1), (("l'avait", 'fait'), 1), (('—', 'Voyons'), 1), (('do', 'la'), 1), (('ae', 'la'), 1), (('La', 'salle'), 1), (('et', 'M.'), 1), (('Bertrand', 'mem'), 1), (('d', "'une"), 1), (("d'âge", 'En'), 1), (('a', 'fait'), 1), (('après', "qu'il"), 1), (('Je', 'lui'), 1), (('a', 'donné'), 1), (('après', 'son'), 1), (('Une', 'grande'), 1), (('a', 'été'), 1), (('On', 'venait'), 1), (('le', 'salua'), 1), (('lit', "l'extrait"), 1), (('dit', '«'), 1), (("c'est", 'peut-'), 1), (('vingt-deux', 'fois'), 1), (("d'assi", 'ses'), 1), (('stigmatise', 'le'), 1), (('La', 'pauvre'), 1), (('lui', 'a'), 1), (('Calmon', 'Gilnert-Boucher'), 1), (('le', 'préfet'), 1), (("d'âge", 'monte'), 1), (("d'âge", 'fait'), 1), (("d'âge", 'est'), 1), (('cet', 'homme'), 1), (('etc', 'Aussi'), 1), (('est', 'court'), 1), (('Alors', 'vous'), 1), (('balsamo', 'Quel'), 1), (('Et', 'cependant'), 1), (('Est-ce', 'vrai'), 1), (('Je', 'le'), 1), (('Parlez', 'maître'), 1), (('BalSCtVM', 'r'), 1), (('du', 'cer'), 1), (('Il', 'quitte'), 1), (('une', 'démission'), 1), (('a', 'résolu'), 1), (('ajouta', 'Mont'), 1), (('»', 'Alors'), 1), (('pour', 'que'), 1), (('Grévy', "s'est"), 1), (('du', 'comité'), 1), (('A.', 'Baudon'), 1), (('du', 'Comité'), 1), (("d'honneur", 'Ces'), 1), (('déclare', 'que'), 1), (('Aux', 'termes'), 1), (('res', 'pectueusement'), 1), (('M.', 'Fresneau'), 1), (('et', 'moi'), 1), (('qui', 'est'), 1), (('de', "l'Assemblée"), 1), (('La', 'proposition'), 1), (('Je', 'ne'), 1), (('Monsieur', 'do'), 1), (('Vous', "n'avez"), 1), (('Je', 'dois'), 1), (("L'Assemblée", 'a'), 1), (('..', 'Je'), 1), (("s'adresse", 'pour'), 1), (('Je-supplie', "l'Assembléa"), 1), (('pour', 'nous'), 1), (('i', '«'), 1), (('etc.', 'etc'), 1), (('des', 'vice-prési'), 1), (('pour', "l'année"), 1), (('de', 'section'), 1)]

# %%
# Create a list of two-grams in the tokenized text for block 2
two_grams_block_3_before = []
two_grams_block_3_after = []



for doc in block3["tokens"]:
    doc = [word for word in doc if word not in punctuations and not word.isdigit()]
    for i in range(len(doc)):
        if doc[i] == ("président"):
            if i > 1:
                two_grams_block_3_before.append((doc[i-2], doc[i-1]))
            if i < len(doc)-3:
                two_grams_block_3_after.append((doc[i+1], doc[i+2]))




# Compute the frequency distribution of the tri-grams for block 1
freq_dist_block_3_before = FreqDist(two_grams_block_3_before)
freq_dist_block_3_after = FreqDist(two_grams_block_3_after)

with open("two-grams-output_president.txt", "a") as file:
    # Write the two-grams before "président"
    file.write("-------------------------BLOCK_3-----------------------Two-grams before 'président':\n")
    for two_gram in two_grams_block_2_before:
        file.write(f"{two_gram[0]} {two_gram[1]}\n")
    # Write the two-grams after "président"
    file.write("-------------------------BLOCK_3-----------------------Two-grams after 'président':\n")
    for two_gram in two_grams_block_2_after:
        file.write(f"{two_gram[0]} {two_gram[1]}\n")



# Print all occurrences of the tri-gram "président" in block of tokenized text
print("Block 3 (1880-1900): \n")
print(f"2-grams before 'le président': \n")
print(two_grams_block_3_before, "\n")
print(f"2-grams after 'le président': \n")
print(two_grams_block_3_after, "\n")
print("Most common 2-grams before: \n")
print(freq_dist_block_3_before.most_common(), "\n")
print("Most common 2-grams after: \n")
print(freq_dist_block_3_after.most_common())
# Out:
# Block 3 (1880-1900):
#
# 2-grams before 'le président':
#
# [('nations', 'de'), ('choisi', 'comme'), ('Gambetta', 'restera'), ('M.', 'le'), ('Cernes-', 'son'), ('M.', 'Ballot'), ('lettres', 'au'), ('réunion', 'le'), ('ihilitairp', 'du'), ('envoyé', 'au'), ('M.', 'Béhic'), ('appelez', 'plus'), ('nom', 'du'), ('proclamer', 'Boulanger'), ('obtenir', 'du'), ('M.', 'le'), ('remis', 'au'), ('monsieur', 'le'), ('MM', 'Beernaert'), ('M.', 'Casimir-Perier'), ('que', 'le'), ('Lilas', 'Seine'), ('tude', 'du'), ('maïuei-sa.di', 'carnot'), ('hier', 'le'), ('par', 'leur'), ('Combes', 'vice-'), ('Comptes', 'le'), ('M.', 'Burdeau'), ('M.', 'Dupuy'), ('adresse', 'au'), ('Monsieur', 'le'), ('monsieur', 'le'), ('êtes', "l'honorable"), ('vous', 'leur'), ('programme', 'du'), ('Gironde', 'le'), ('venue', 'du'), ('Le', 'Lorrain'), ('pasteur', 'Bourlier'), ('après', 'étant'), ('M.', 'le'), ('M.', 'le'), ('M.', 'le'), ('résignée', 'du'), ('par', 'son'), ('veaux', 'le'), ('par', 'le'), ('crétionnaire', 'du'), ('4e', 'leur'), ('probablement', 'leur'), ("d'usage", 'au'), ('dé', "l'ancien-"), ('en', 'droit'), ("l'intérieur", 'Belarbre'), ('TOURGNOL', 'Le'), ('M.', 'Loubet'), ('ser', 'le'), ('de', 'leur'), ('de', 'leur'), ('cet', 'ancien'), ('devant', 'le'), ('noncent', 'au'), ('Chambre', 'Le'), ('Loubet', 'pour'), ('accuse', 'le'), ('que', 'le'), ('Méline', 'Le'), ('M.', 'le'), ('si', 'le'), ('Et', "l'ancien"), ('M.', 'Loubet'), ('serait', 'un'), ('voix', 'du'), ('Le', 'nouveau'), ('Là-', 'nouvelle'), ('rébarbatives', 'du'), ('Nautes', 'Le'), ('pend', 'du'), ('P.', 'Laurens'), ('Raffalovich', 'vice-'), ('G.', 'Blanc'), ('a', 'pour'), ('défini', 'Le'), ('fonctions', 'do'), ('M.', 'Waldeck-Rousseau'), ('émouvant', 'le'), ('Puis', 'le'), ('de', 'Palikao'), ('adressée', 'le'), ('et', 'du'), ("s'agitent", 'le'), ('Main', 'Le'), ('Parole', 'mon'), ("l'arrivée", 'du'), ('journée', 'du'), ('A', "l'invulnérable"), ('transmet', 'au')]
#
# 2-grams after 'le président':
#
# [('des', 'vice-prési'), ('pour', "l'année"), ('de', 'la'), ('du', 'Conseil'), ('du', 'Conseil'), ('de', 'section'), ('de', 'la'), ('a', 'vivement'), ('de', 'la'), ('von', 'Wedell'), ('du', 'Conseil'), ('I', 'ans'), ('de', 'la'), ("d'honneur", 'de'), ('Grévy', 'Quittance'), ('Le', 'Royer'), ('la', 'déclaration'), ('d', 'o.uvrir.Ia'), ('du', 'Conseil'), ('de', 'la'), ('..', '«'), ('M.', 'le'), ('Dupuy', 'Mais'), ('de', 'la'), ('et', 'les'), ('M.', 'Aùdiffred'), ('dû', 'Sénat'), ('du', 'Tribunal'), ('de', 'la'), ('du', 'Conseil'), ('de', 'la'), ('que', 'je'), ('que', 'si'), ('aura', 'pour'), ('combien', 'Sa'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Conseil'), ('de', 'la'), ('de', 'la'), ('du', 'Sénat'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Conseil'), ('Abrahamowicz', 'et'), ('M.', 'Simson'), ('effectif', "d'une"), ('des', 'assises'), ('des', 'Assises'), ('a', 'donné'), ('va', 'indiquer'), ('du', 'Sénat'), ('de', 'la'), ('près', 'de'), ('du', 'Conseil'), ('de', 'la'), ('du', 'Sénat'), ('du', 'Sénat'), ('et', 'vaincre'), ('M.', 'Barthou'), ('du', 'Conseil'), ('du', 'Sénat'), ('du', 'Conseil'), ('du', 'Sénat'), ('de', 'la'), ('du', 'Sénat'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Sénat'), ('du', 'Conseil'), ('du', 'Sénat'), ('de', 'combat'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Cercle'), ('Kriiger', 'de'), ('—', 'Il'), ('de', 'la'), ('de', 'la'), ('de', 'la'), ('du', 'Comité'), ('M.', 'Léon'), ('du', 'groupe'), ('du', 'Conseilles'), ('du', 'Conseil'), ('prit', 'la'), ('Schneider', 'proposa'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Conseil'), ('Kruger', 'est'), ('du', 'Tribunal'), ('...', 'même'), ('boer', "s'est"), ('Krûger', 'Il'), ('Kroger', 'le'), ('Kriiger', "l'expression")]
#
# Most common 2-grams before:
#
# [(('M.', 'le'), 6), (('monsieur', 'le'), 2), (('que', 'le'), 2), (('M.', 'Loubet'), 2), (('de', 'leur'), 2), (('nations', 'de'), 1), (('choisi', 'comme'), 1), (('Gambetta', 'restera'), 1), (('Cernes-', 'son'), 1), (('M.', 'Ballot'), 1), (('lettres', 'au'), 1), (('réunion', 'le'), 1), (('ihilitairp', 'du'), 1), (('envoyé', 'au'), 1), (('M.', 'Béhic'), 1), (('appelez', 'plus'), 1), (('nom', 'du'), 1), (('proclamer', 'Boulanger'), 1), (('obtenir', 'du'), 1), (('remis', 'au'), 1), (('MM', 'Beernaert'), 1), (('M.', 'Casimir-Perier'), 1), (('Lilas', 'Seine'), 1), (('tude', 'du'), 1), (('maïuei-sa.di', 'carnot'), 1), (('hier', 'le'), 1), (('par', 'leur'), 1), (('Combes', 'vice-'), 1), (('Comptes', 'le'), 1), (('M.', 'Burdeau'), 1), (('M.', 'Dupuy'), 1), (('adresse', 'au'), 1), (('Monsieur', 'le'), 1), (('êtes', "l'honorable"), 1), (('vous', 'leur'), 1), (('programme', 'du'), 1), (('Gironde', 'le'), 1), (('venue', 'du'), 1), (('Le', 'Lorrain'), 1), (('pasteur', 'Bourlier'), 1), (('après', 'étant'), 1), (('résignée', 'du'), 1), (('par', 'son'), 1), (('veaux', 'le'), 1), (('par', 'le'), 1), (('crétionnaire', 'du'), 1), (('4e', 'leur'), 1), (('probablement', 'leur'), 1), (("d'usage", 'au'), 1), (('dé', "l'ancien-"), 1), (('en', 'droit'), 1), (("l'intérieur", 'Belarbre'), 1), (('TOURGNOL', 'Le'), 1), (('ser', 'le'), 1), (('cet', 'ancien'), 1), (('devant', 'le'), 1), (('noncent', 'au'), 1), (('Chambre', 'Le'), 1), (('Loubet', 'pour'), 1), (('accuse', 'le'), 1), (('Méline', 'Le'), 1), (('si', 'le'), 1), (('Et', "l'ancien"), 1), (('serait', 'un'), 1), (('voix', 'du'), 1), (('Le', 'nouveau'), 1), (('Là-', 'nouvelle'), 1), (('rébarbatives', 'du'), 1), (('Nautes', 'Le'), 1), (('pend', 'du'), 1), (('P.', 'Laurens'), 1), (('Raffalovich', 'vice-'), 1), (('G.', 'Blanc'), 1), (('a', 'pour'), 1), (('défini', 'Le'), 1), (('fonctions', 'do'), 1), (('M.', 'Waldeck-Rousseau'), 1), (('émouvant', 'le'), 1), (('Puis', 'le'), 1), (('de', 'Palikao'), 1), (('adressée', 'le'), 1), (('et', 'du'), 1), (("s'agitent", 'le'), 1), (('Main', 'Le'), 1), (('Parole', 'mon'), 1), (("l'arrivée", 'du'), 1), (('journée', 'du'), 1), (('A', "l'invulnérable"), 1), (('transmet', 'au'), 1)]
#
# Most common 2-grams after:
#
# [(('du', 'Conseil'), 24), (('de', 'la'), 16), (('du', 'Sénat'), 9), (('du', 'Tribunal'), 2), (('des', 'vice-prési'), 1), (('pour', "l'année"), 1), (('de', 'section'), 1), (('a', 'vivement'), 1), (('von', 'Wedell'), 1), (('I', 'ans'), 1), (("d'honneur", 'de'), 1), (('Grévy', 'Quittance'), 1), (('Le', 'Royer'), 1), (('la', 'déclaration'), 1), (('d', 'o.uvrir.Ia'), 1), (('..', '«'), 1), (('M.', 'le'), 1), (('Dupuy', 'Mais'), 1), (('et', 'les'), 1), (('M.', 'Aùdiffred'), 1), (('dû', 'Sénat'), 1), (('que', 'je'), 1), (('que', 'si'), 1), (('aura', 'pour'), 1), (('combien', 'Sa'), 1), (('Abrahamowicz', 'et'), 1), (('M.', 'Simson'), 1), (('effectif', "d'une"), 1), (('des', 'assises'), 1), (('des', 'Assises'), 1), (('a', 'donné'), 1), (('va', 'indiquer'), 1), (('près', 'de'), 1), (('et', 'vaincre'), 1), (('M.', 'Barthou'), 1), (('de', 'combat'), 1), (('du', 'Cercle'), 1), (('Kriiger', 'de'), 1), (('—', 'Il'), 1), (('du', 'Comité'), 1), (('M.', 'Léon'), 1), (('du', 'groupe'), 1), (('du', 'Conseilles'), 1), (('prit', 'la'), 1), (('Schneider', 'proposa'), 1), (('Kruger', 'est'), 1), (('...', 'même'), 1), (('boer', "s'est"), 1), (('Krûger', 'Il'), 1), (('Kroger', 'le'), 1), (('Kriiger', "l'expression"), 1)]

# %%
# Create a list of two-grams in the tokenized text for block 2
two_grams_block_4_before = []
two_grams_block_4_after = []



for doc in block4["tokens"]:
    doc = [word for word in doc if word not in punctuations and not word.isdigit()]
    for i in range(len(doc)):
        if doc[i] == ("président"):
            if i > 1:
                two_grams_block_4_before.append((doc[i-2], doc[i-1]))
            if i < len(doc)-3:
                two_grams_block_4_after.append((doc[i+1], doc[i+2]))




# Compute the frequency distribution of the tri-grams for block 1
freq_dist_block_4_before = FreqDist(two_grams_block_4_before)
freq_dist_block_4_after = FreqDist(two_grams_block_4_after)

with open("two-grams-output_president.txt", "a") as file:
    # Write the two-grams before "président"
    file.write("-------------------------BLOCK_4-----------------------Two-grams before 'président':\n")
    for two_gram in two_grams_block_2_before:
        file.write(f"{two_gram[0]} {two_gram[1]}\n")
    # Write the two-grams after "président"
    file.write("-------------------------BLOCK_4-----------------------Two-grams after 'président':\n")
    for two_gram in two_grams_block_2_after:
        file.write(f"{two_gram[0]} {two_gram[1]}\n")


# Print all occurrences of the tri-gram "président" in block of tokenized text
print("Block 4 (1900-1920): \n")
print(f"2-grams before 'le président': \n")
print(two_grams_block_4_before, "\n")
print(f"2-grams after 'le président': \n")
print(two_grams_block_4_after, "\n")
print("Most common 2-grams before: \n")
print(freq_dist_block_4_before.most_common(), "\n")
print("Most common 2-grams after: \n")
print(freq_dist_block_4_after.most_common())
# Out:
# Block 4 (1900-1920):
#
# 2-grams before 'le président':
#
# [('a', 'pour'), ('défini', 'Le'), ('fonctions', 'do'), ('M.', 'Waldeck-Rousseau'), ('émouvant', 'le'), ('Puis', 'le'), ('de', 'Palikao'), ('adressée', 'le'), ('et', 'du'), ("s'agitent", 'le'), ('Main', 'Le'), ('Parole', 'mon'), ("l'arrivée", 'du'), ('journée', 'du'), ('A', "l'invulnérable"), ('transmet', 'au'), ('M.', 'le'), ('hier', 'au'), ('est', "l'ancien"), ('nommait', 'le'), ('sujet', 'le'), ('t', "d'EscIands"), ('la-Reine', 'Le'), ('dit', 'le'), ("'Etat", 'et'), ('Villa', 'le'), ('Al', 'le'), ('H.', 'Hyde'), ('docteur', 'Harper'), ('le', 'jeune'), ('membre', 'ou'), ('Bourgeois', 'en'), ('Membre', 'et'), ('dont', 'le'), ('à', 'son'), ('ce', 'vice-'), ('était', 'élu'), ('croque-mort', 'Son'), ('Jockey', 'le'), ('Roger', 'Ballu'), ('Petit', 'vice-'), ('comme', 'son'), ('sée', 'du'), ('par', 'le'), ('part', 'du'), ('M.', 'le'), ('M.', 'le'), ('et', 'son'), ('M.', 'Combes'), ('lais', 'du'), ('M.', 'le'), ('M.', 'le'), ('scientifique', 'le'), ('Sou-', 'chon'), ('G.', 'Poisson'), ('Pi', 'geon'), ('E.', 'Gras'), ('GailIon', 'Chocarne'), ('C.', 'Chevillet'), ('il', 'était'), ('trouver', 'un'), ('que', 'ce'), ('yeux', 'du'), ('an', 'cien'), ('du', 'nouveau'), ('M.', 'le'), ('le', 'nouveau'), ('à', 'la'), ('espérait', 'Le'), ("l'autorité", 'du'), ('par', 'le'), ('lés', "tombes'dU"), ('présente', 'le'), ('ment', 'le'), ('M.', 'Brousse'), ('MM', 'Rouvier'), ("l'absence", 'du'), ('Paul', 'Brousse'), ('avec', 'le'), ("l'Institut", 'et'), ('Groningue', 'et'), ('de', "l'ancien"), ("l'absence", 'du'), ('fureurs', 'le'), ('M.', 'le'), ('M.', 'Dalliba'), ('socié', 'le'), ('Sarrien', 'ancien'), ('pour', 'le'), ('celui', 'de'), ('condamnés.', 'Le'), ('des', 'sceaux'), ('par', 'son'), ('conseiller', "d'Etat"), ('arrondissement', 'Létang'), ('fut', 'nommé'), ('M.', 'Bonnat'), ('du', 'premier'), ('Manche', 'Papin'), ('un', 'ancien'), ('un', 'ancien'), ('an', 'cien-'), ('bureau', 'du'), ('Le', 'nouveau'), ("d'être", 'réélu'), ('installé', 'comme'), ('lettre', 'du'), ('lettre', 'au'), ('Roosevelt', 'Le'), ('Mar-', 'gueritte'), ('que', "l'émineht"), ('par', 'le'), ('—', 'le'), ('auprès', 'du'), ('rast', "l'ancien"), ('Nénot', 'le'), ('et', 'le'), ('où', "l'ancien"), ('Luxembourg', 'le'), ('est', 'le'), ('crime', 'Le'), ('du', 'poète-'), ("l'incident", 'du'), ('Monsieur', 'le'), ('..', 'Aubinel'), ('surveillent', "l'ancien"), ("l'armée", 'le'), ('M.', 'Ablett'), ('musée', 'le'), ('par', 'le'), ('envers', 'le'), ('vériser', 'Le'), ('contester', 'le'), ('est', 'le'), ('Lavandou', 'le'), ('Correctionnelle', 'le'), ('gauche', 'Le'), ('avec', 'le'), ("qu'il", 'était'), ('comme', '«'), ('étant', 'élu'), ('marbre', 'Notre'), ('Beaumetz', 'Roll'), ('mouvement', 'comme'), ('filles', 'du'), ('Monroe', 'du'), ('nièce', 'du'), ('fille', 'du'), ('ceux', 'du'), ('était', 'depuis'), ('trente', 'ans'), ('M.', 'Chérioux'), ('a', 'pour'), ('■', 'Le'), ('qui', 'sera'), ('qui', 'fut'), ('M.', 'le'), ('efforts', 'du'), ('fenêtres', 'du'), ('château', 'Le'), ('M.', 'Clemenceau'), ('de', 'Malynski'), ('Jean', 'Lahor'), ('M.', 'Chénoux'), ('M.', 'Clemenceau'), ('Lot-et-Garonne', 'et'), ('par', 'acclamation'), ('candidature', "L'ancien"), ('M.', 'Roll'), ('qui', 'fut'), ('dernier', 'Le'), ('hommage', 'au'), ('parole', 'au'), ('parole', 'au'), ('Poitevin', 'nommé'), ('infa', 'tigable'), ('quand', 'le'), ('lière', 'Le'), ('M.', 'Nénot'), ('Guillot', 'le'), ('général', 'Poulléau'), ('grève', 'Le'), ('monsieur', 'le'), ('monsieur', 'le'), ("l'élection", 'du'), ('par', 'un'), ('M.', 'Orenga'), ('etc', 'Le'), ("L'EXTERMINATEUR", 'Le'), ('M.', 'Boisselet'), ('de', "l'Institut"), ('que', 'le'), ('Le', 'nouveau'), ('par', 'son'), ('M.', 'Lefort'), ('impériale', 'et'), ('Rhallys', "l'ancien"), ('Les', "projets'Ùu"), ('•', "t'hënorable"), ('Monsieur', 'Je'), ('Mi', 'le'), ('M.', 'le'), ('M.', 'le'), ('M.', 'le'), ('du', 'dévoué'), ('Le', 'huitième'), ('son', 'nouveau'), ('Stéphane', 'Dervillé'), ('de', 'Battersea'), ("l'honneur", 'du'), ('et', 'ancien'), ('Paris', 'Le'), ('corps', "d' ...
#
# 2-grams after 'le président':
#
# [('M.', 'Léon'), ('du', 'groupe'), ('du', 'Conseilles'), ('du', 'Conseil'), ('prit', 'la'), ('Schneider', 'proposa'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Conseil'), ('Kruger', 'est'), ('du', 'Tribunal'), ('...', 'même'), ('boer', "s'est"), ('Krûger', 'Il'), ('Kroger', 'le'), ('Kriiger', "l'expression"), ('du', 'Conseil'), ('du.Conseil', 'et'), ('de', 'la'), ('Le-', 'febvre'), ('du', 'Conseil'), ('aux', 'mem'), ('de', 'la'), ('à', 'ne'), ('du', 'groupe'), ('de', 'la'), ('Kriiger', 'Mais'), ('de', 'la'), ('de', "l'université"), ('de', 'la'), ('des', 'grandes'), ('de', 'la'), ('du', 'Conseil'), ('est', 'M.'), ('de', 'qui'), ("n'était", 'autrè'), ('de', 'la'), ('se', 'lève'), ('M-', 'le'), ('Georges', 'Petit'), ('Besnard', 'Dubùfe'), ('et', 'à'), ('M.', 'O.'), ('du', 'Conseil'), ('Roosevelt', 'et'), ('du', 'Conseil'), ('du', 'Conseil'), ('le', 'comte'), ('du', 'Conseil'), ('de', 'la'), ('du', 'Conseil'), ('du', 'Conseil'), ('des', 'Etats-Unis'), ('du', 'Comité'), ('du', 'Comité'), ('de', 'la'), ('du', 'Comité'), ('du', 'Co'), ('du', 'quartier'), ('avant', 'de'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Conseil'), ('et', 'des'), ('du', 'Conseil'), ('du', 'Conseil'), ('de', 'la'), ('du', 'Conseil'), ('du', 'Conseil'), ('M.', 'Noguères'), ('Carnot', 'et'), ('de', "l'Association"), ('et', 'les'), ('du', 'Conseil'), ('du', 'Conseil'), ('M.', 'Landrin'), ('du', 'Conseil'), ('du', 'Conseil'), ('de', "l'Ecole"), ('de', 'la'), ('du', 'Conseil'), ('du', 'Conseil'), ('du', 'Consejl'), ('du', 'Conseil'), ('de', 'la'), ('la', 'Chambre'), ('du', 'Conseil'), ('des', 'Etats-Unis'), ('du', 'Sénat'), ('du', 'Conseil'), ('de', 'trois'), ('M.', 'de'), ('du', 'Conseil'), ('du', 'Comité'), ('et', 'rapporteur'), ('du', 'Comité'), ('qui', "s'était"), ('de', 'la'), ('du', 'Conseil'), ('de', "l'Assemblée"), ('de', 'la'), ('et', 'au-dessous'), ('veut', 'jusque-là'), ('de', 'la'), ('de', 'Chambre'), ('du', 'Conseil'), ('Roosevelt', 'Le'), ('Roosevelt', 'se'), ('de', 'la'), ('de', "l'Union"), ('«', 'Il'), ('du', 'Conseil'), ('du', 'Conseil'), ('de', "l'Assemblée"), ("d'hier", 'de'), ("d'aujourd'hui", 'de'), ('de', 'la'), ('de', 'la'), ('Cette', 'année-ci'), ('du', 'Conseil'), ('Stpphen', 'Liéyeard'), ('de', 'Chambre'), ('du', 'Conseil'), ('du', 'comité'), ('du', 'comité'), ('du', 'Conseil'), ('et', 'les-membres'), ('du', 'Conseil'), ('et', 'les'), ('de', 'la'), ('du', 'Conseil'), ('du', 'Conseil'), ('Magnaud', 'député'), ('Ma£', 'uaud'), ('a', 'interrogé'), ('au', 'témoin'), ('du', 'Conseil'), ('du', 'Sénat'), ('»', "d'une"), ('du', 'Club'), ("d'hon", 'neur'), ('et', 'les'), ('de', 'Cham'), ('Monroe', 'du'), ('Tyler', 'avec'), ('Buclianan', 'avec'), ('Grant', 'et'), ('Cle-', 'veland'), ('du', 'Jockey-Club'), ('en', 'et'), ('du', 'Conseil'), ('M.', 'Tournois'), ('doucement', '—'), ('l', 'an'), ('de', 'la'), ('de', 'la'), ('Iioo§evcit', 'un'), ('du', 'Conseil'), ('de', 'la'), ('du', 'Conseil'), ('de', "l'Ecole"), ('de', 'la'), ('du', 'Conseil'), ('du', 'Conseil'), ('de', 'la'), ('de', 'la'), ('du', 'conseil'), ('et', 'aux'), ('du', 'Pérou'), ('M.', 'P.'), ('Taft', "d'un"), ('la', 'lui'), ("C'est", 'à'), ('de', 'séance'), ('du', 'comité'), ('de', 'la'), ('du', 'Conseil'), ('de', 'la'), ('Elandin', 'M.'), ('de', 'la'), ("d'une", 'de'), ('—', 'Je'), ('r', 'mais'), ('Mac', 'Kinley'), ('aussi', 'aimable'), ('du', 'Tribunal'), ('du', '«'), ('Roôsevelt', 'a'), ('du', 'comité'), ('de', 'la'), ('Roosevelt', 'tirera'), ('du', 'Conseil'), ('au', 'sous-secrétaire'), ("de-l'Aca", 'démie'), ('du', 'Conseil'), ('du', 'Conseil'), ('Bonjeari', 'Une'), ('du', 'Conseil'), ('dis-je', "pardonnez'-"), ('de', 'Vallès'), ('de', 'Vallès'), ('de', 'Vallès'), ('Borijean', "de'fonder"), ('de', 'cette'), ("C'est", 'après-demain'), ('successeur', 'de'), ('du', 'P.'), ('du', 'Local'), ('Roo-', 'sevelt'), ('du', 'Conseil'), ('de', 'la'), ('des', 'hautes'), ('Albert', 'Besnard'), ('du', 'Conseil'), ('et', 'secrétaire'), ('de', 'la'), ('des', 'Assises'), ('du', ...
#
# Most common 2-grams before:
#
# [(('M.', 'le'), 21), (('par', 'le'), 7), (('M.', 'Clemenceau'), 5), (('de', "l'ancien"), 4), (('est', 'le'), 4), (('que', 'le'), 4), (('avec', 'le'), 3), (('et', 'le'), 3), (('le', 'premier'), 3), (('M.', 'Millerand'), 3), (('a', 'pour'), 2), (('dit', 'le'), 2), (('dont', 'le'), 2), (('il', 'était'), 2), (('le', 'nouveau'), 2), (("l'absence", 'du'), 2), (('par', 'son'), 2), (('un', 'ancien'), 2), (('Le', 'nouveau'), 2), (('auprès', 'du'), 2), (('Monsieur', 'le'), 2), (('envers', 'le'), 2), (('■', 'Le'), 2), (('qui', 'fut'), 2), (('parole', 'au'), 2), (('monsieur', 'le'), 2), (('et', 'ancien'), 2), (('Paris', 'Le'), 2), (('•', 'Le'), 2), (('Ni', 'le'), 2), (('Mais', 'le'), 2), (('défini', 'Le'), 1), (('fonctions', 'do'), 1), (('M.', 'Waldeck-Rousseau'), 1), (('émouvant', 'le'), 1), (('Puis', 'le'), 1), (('de', 'Palikao'), 1), (('adressée', 'le'), 1), (('et', 'du'), 1), (("s'agitent", 'le'), 1), (('Main', 'Le'), 1), (('Parole', 'mon'), 1), (("l'arrivée", 'du'), 1), (('journée', 'du'), 1), (('A', "l'invulnérable"), 1), (('transmet', 'au'), 1), (('hier', 'au'), 1), (('est', "l'ancien"), 1), (('nommait', 'le'), 1), (('sujet', 'le'), 1), (('t', "d'EscIands"), 1), (('la-Reine', 'Le'), 1), (("'Etat", 'et'), 1), (('Villa', 'le'), 1), (('Al', 'le'), 1), (('H.', 'Hyde'), 1), (('docteur', 'Harper'), 1), (('le', 'jeune'), 1), (('membre', 'ou'), 1), (('Bourgeois', 'en'), 1), (('Membre', 'et'), 1), (('à', 'son'), 1), (('ce', 'vice-'), 1), (('était', 'élu'), 1), (('croque-mort', 'Son'), 1), (('Jockey', 'le'), 1), (('Roger', 'Ballu'), 1), (('Petit', 'vice-'), 1), (('comme', 'son'), 1), (('sée', 'du'), 1), (('part', 'du'), 1), (('et', 'son'), 1), (('M.', 'Combes'), 1), (('lais', 'du'), 1), (('scientifique', 'le'), 1), (('Sou-', 'chon'), 1), (('G.', 'Poisson'), 1), (('Pi', 'geon'), 1), (('E.', 'Gras'), 1), (('GailIon', 'Chocarne'), 1), (('C.', 'Chevillet'), 1), (('trouver', 'un'), 1), (('que', 'ce'), 1), (('yeux', 'du'), 1), (('an', 'cien'), 1), (('du', 'nouveau'), 1), (('à', 'la'), 1), (('espérait', 'Le'), 1), (("l'autorité", 'du'), 1), (('lés', "tombes'dU"), 1), (('présente', 'le'), 1), (('ment', 'le'), 1), (('M.', 'Brousse'), 1), (('MM', 'Rouvier'), 1), (('Paul', 'Brousse'), 1), (("l'Institut", 'et'), 1), (('Groningue', 'et'), 1), (('fureurs', 'le'), 1), (('M.', 'Dalliba'), 1), (('socié', 'le'), 1), (('Sarrien', 'ancien'), 1), (('pour', 'le'), 1), (('celui', 'de'), 1), (('condamnés.', 'Le'), 1), (('des', 'sceaux'), 1), (('conseiller', "d'Etat"), 1), (('arrondissement', 'Létang'), 1), (('fut', 'nommé'), 1), (('M.', 'Bonnat'), 1), (('du', 'premier'), 1), (('Manche', 'Papin'), 1), (('an', 'cien-'), 1), (('bureau', 'du'), 1), (("d'être", 'réélu'), 1), (('installé', 'comme'), 1), (('lettre', 'du'), 1), (('lettre', 'au'), 1), (('Roosevelt', 'Le'), 1), (('Mar-', 'gueritte'), 1), (('que', "l'émineht"), 1), (('—', 'le'), 1), (('rast', "l'ancien"), 1), (('Nénot', 'le'), 1), (('où', "l'ancien"), 1), (('Luxembourg', 'le'), 1), (('crime', 'Le'), 1), (('du', 'poète-'), 1), (("l'incident", 'du'), 1), (('..', 'Aubinel'), 1), (('surveillent', "l'ancien"), 1), (("l'armée", 'le'), 1), (('M.', 'Ablett'), 1), (('musée', 'le'), 1), (('vériser', 'Le'), 1), (('contester', 'le'), 1), (('Lavandou', 'le'), 1), (('Correctionnelle', 'le'), 1), (('gauche', 'Le'), 1), (("qu'il", 'était'), 1), (('comme', '«'), 1), (('étant', 'élu'), 1), (('marbre', 'Notre'), 1), (('Beaumetz', 'Roll'), 1), (('mouvement', 'comme'), 1), (('filles', 'du'), 1), (('Monroe', 'du'), 1), (('nièce', 'du'), 1), (('fille', 'du'), 1), (('ceux', 'du'), 1), (('était', 'depuis'), 1), (('trente', 'ans'), 1), (('M.', 'Chérioux'), 1), (('qui', 'sera'), 1), (('efforts', 'du'), 1), (('fenêtres', 'du'), 1), (('château', 'Le'), 1), (('de', 'Malynski'), 1), (('Jean', 'Lahor'), 1), (('M.', 'Chénoux'), 1), (('Lot-et-Garonne', 'et'), 1), (('par', 'acclamation'), 1), (('candidature', "L'ancien"), 1), (('M.', 'Roll'), 1), (('dernier', 'Le'), 1), (('hommage', 'au'), 1), (('Poitevin', 'nommé'), 1), (('infa', 'tigable'),  ...
#
# Most common 2-grams after:
#
# [(('du', 'Conseil'), 132), (('de', 'la'), 47), (('du', 'Tribunal'), 5), (('des', 'Etats-Unis'), 5), (('du', 'Comité'), 5), (('du', 'comité'), 5), (('du', 'groupe'), 4), (('et', 'les'), 3), (('de', 'Vallès'), 3), (('de', "l'Ecole"), 2), (('du', 'Sénat'), 2), (('de', "l'Assemblée"), 2), (('de', 'Chambre'), 2), (('de', "l'Union"), 2), (('du', 'conseil'), 2), (('de', 'cette'), 2), (('à', 'la'), 2), (('Wilson', 'et'), 2), (('M.', 'Léon'), 1), (('du', 'Conseilles'), 1), (('prit', 'la'), 1), (('Schneider', 'proposa'), 1), (('Kruger', 'est'), 1), (('...', 'même'), 1), (('boer', "s'est"), 1), (('Krûger', 'Il'), 1), (('Kroger', 'le'), 1), (('Kriiger', "l'expression"), 1), (('du.Conseil', 'et'), 1), (('Le-', 'febvre'), 1), (('aux', 'mem'), 1), (('à', 'ne'), 1), (('Kriiger', 'Mais'), 1), (('de', "l'université"), 1), (('des', 'grandes'), 1), (('est', 'M.'), 1), (('de', 'qui'), 1), (("n'était", 'autrè'), 1), (('se', 'lève'), 1), (('M-', 'le'), 1), (('Georges', 'Petit'), 1), (('Besnard', 'Dubùfe'), 1), (('et', 'à'), 1), (('M.', 'O.'), 1), (('Roosevelt', 'et'), 1), (('le', 'comte'), 1), (('du', 'Co'), 1), (('du', 'quartier'), 1), (('avant', 'de'), 1), (('et', 'des'), 1), (('M.', 'Noguères'), 1), (('Carnot', 'et'), 1), (('de', "l'Association"), 1), (('M.', 'Landrin'), 1), (('du', 'Consejl'), 1), (('la', 'Chambre'), 1), (('de', 'trois'), 1), (('M.', 'de'), 1), (('et', 'rapporteur'), 1), (('qui', "s'était"), 1), (('et', 'au-dessous'), 1), (('veut', 'jusque-là'), 1), (('Roosevelt', 'Le'), 1), (('Roosevelt', 'se'), 1), (('«', 'Il'), 1), (("d'hier", 'de'), 1), (("d'aujourd'hui", 'de'), 1), (('Cette', 'année-ci'), 1), (('Stpphen', 'Liéyeard'), 1), (('et', 'les-membres'), 1), (('Magnaud', 'député'), 1), (('Ma£', 'uaud'), 1), (('a', 'interrogé'), 1), (('au', 'témoin'), 1), (('»', "d'une"), 1), (('du', 'Club'), 1), (("d'hon", 'neur'), 1), (('de', 'Cham'), 1), (('Monroe', 'du'), 1), (('Tyler', 'avec'), 1), (('Buclianan', 'avec'), 1), (('Grant', 'et'), 1), (('Cle-', 'veland'), 1), (('du', 'Jockey-Club'), 1), (('en', 'et'), 1), (('M.', 'Tournois'), 1), (('doucement', '—'), 1), (('l', 'an'), 1), (('Iioo§evcit', 'un'), 1), (('et', 'aux'), 1), (('du', 'Pérou'), 1), (('M.', 'P.'), 1), (('Taft', "d'un"), 1), (('la', 'lui'), 1), (("C'est", 'à'), 1), (('de', 'séance'), 1), (('Elandin', 'M.'), 1), (("d'une", 'de'), 1), (('—', 'Je'), 1), (('r', 'mais'), 1), (('Mac', 'Kinley'), 1), (('aussi', 'aimable'), 1), (('du', '«'), 1), (('Roôsevelt', 'a'), 1), (('Roosevelt', 'tirera'), 1), (('au', 'sous-secrétaire'), 1), (("de-l'Aca", 'démie'), 1), (('Bonjeari', 'Une'), 1), (('dis-je', "pardonnez'-"), 1), (('Borijean', "de'fonder"), 1), (("C'est", 'après-demain'), 1), (('successeur', 'de'), 1), (('du', 'P.'), 1), (('du', 'Local'), 1), (('Roo-', 'sevelt'), 1), (('des', 'hautes'), 1), (('Albert', 'Besnard'), 1), (('et', 'secrétaire'), 1), (('des', 'Assises'), 1), (("Cès'trùis", 'personnages'), 1), (('Roosevelt', 'i'), 1), (('honoraire', 'Chaque'), 1), (('des', '■'), 1), (('R^xifeevelt', 'Ta-'), 1), (('La', 'figure'), 1), (('du', 'Syndicat'), 1), (('Saenz', 'PeJ5a-aura'), 1), (('Qulntana', 'dont'), 1), (('Saeiiz', 'Peila'), 1), (('de-la', 'f-'), 1), (('Saenz', 'Peria'), 1), (('constitutionnel', 'et'), 1), (('-ne-', 'disposant'), 1), (('y', 'mettre'), 1), (('..', 'Tous'), 1), (('»', 'Car'), 1), (('du.Conseil', 'très'), 1), (('du', 'con'), 1), (('qui', 'le'), 1), (('Brisson', 'qui'), 1), (('du', 'Conséil'), 1), (('Taft', 'fait'), 1), (("s'il", 'ne'), 1), (('du', 'Sobranié'), 1), (('du', 'Con'), 1), (('pour', 'mener'), 1), (('parut', 'sur'), 1), (('de', 'mé'), 1), (('qui', 'ne'), 1), (('enfin', 'qui'), 1), (('Faure', 'Majesté'), 1), (('Wil', 'son'), 1), (('Wilson', "s'est"), 1), (('Wilson', 'rappelle'), 1), (('Wilson', '11e'), 1), (('Wilson', 'ni'), 1), (('Wilson', 'cependant'), 1), (('Sarrut', 'A'), 1), (('Teste', "n'était"), 1), (('Wilson', 'pour'), 1), (('``', 'Wilson'), 1), (('Wilson', 'LE'), 1), (("du'Conseil", 'avec'), 1), (('ac', 'tuel'), 1), (('dont', 'les'), 1), (('provis ...

# %% [markdown]
# ## Concordance analysis:
#
# ### A concordance analysis can help us identify the contexts in which the word 'président' appears. We use the NLTK library that has a Text.concordance() method that we can use to generate a concordance for a word in our corpus.

# %%
from nltk.text import Text

# Create a list of token strings for each block
block1_tokens = [token for doc in block1["tokens"] for token in doc]
block2_tokens = [token for doc in block2["tokens"] for token in doc]
block3_tokens = [token for doc in block3["tokens"] for token in doc]
block4_tokens = [token for doc in block4["tokens"] for token in doc]

# Create a Text object for each block
text_block_1 = Text(block1_tokens)
text_block_2 = Text(block2_tokens)
text_block_3 = Text(block3_tokens)
text_block_4 = Text(block4_tokens)


with open("key-word-in-context-president.txt ", "w") as file :
    file.write("----------------------BLOCK-1-------------------------- \n")
    for line in text_block_1.concordance_list("président", lines=22):
        file.write(line.line + "\n")
    file.write("----------------------BLOCK-2-------------------------- \n")
    for line in text_block_2.concordance_list("président", lines=727):
        file.write(line.line + "\n")
    file.write("----------------------BLOCK-3-------------------------- \n")
    for line in text_block_3.concordance_list("président", lines=793):
        file.write(line.line + "\n")
    file.write("----------------------BLOCK-4-------------------------- \n")
    for line in text_block_4.concordance_list("président", lines=708):
        file.write(line.line + "\n")
    

# Perform a concordance analysis for the word "président" in each block
print("Concordance analysis for 'président' in Block 1:")
text_block_1.concordance("président")
print("\nConcordance analysis for 'président' in Block 2:")
text_block_2.concordance("président")
print("\nConcordance analysis for 'président' in Block 3:")
text_block_3.concordance("président")
print("\nConcordance analysis for 'président' in Block 4:")
text_block_4.concordance("président")
# Out:
# Concordance analysis for 'président' in Block 1:
# no matches
#
# Concordance analysis for 'président' in Block 2:
# Displaying 25 of 197 matches:
# ne foule énorme , et quoique M. le président du saint- office eût déclaré depui
# l'ouverture de l'tudience. , M. le président procède à l'interrogatoire de l'ac
# ilée , et mon pays , Florence . le président Dis Ion âge . ^ galilée Soixante e
# ^ galilée Soixante et dix ans . le président Ton état ? galilée Philosophe . po
#  mens ! — Sophiste ! Scélérat ! le président Ne professes-tu pas ? galilée Oui
# rofesses-tu pas ? galilée Oui . le président D'après quels systèmes ? galilée D
# nature , et lisez l'univers . » le président , montrant un hvre a Galilée . Ce
# broise Thomas ( de l'Ijnsfitut ) , président ; Berlioz ( de l'Institut ) , East
# trè de chapelle de Saint-Roch et ' président de la société académique de musiqu
# nnes l'invi tation suivante : « Le président et les membres de la salle d'armes
#  missaires du gouvernement . m. le président schneider . La parole est à M. Lan
# ion sur . quelques bancs . ) m. le président sçhneidçb . Si les interrup- 1 tio
# la gauche de l'orateur . ) si . le président S chneider . La parole est à M. Gu
# vement . — Bruits divers . ) m. le président schneider . Né ( faites pas de per
# à la-droite de l'orateur . ) H. LE PRÉSIDENT SCHNEIDER . Il y a eu COHnsott- na
#  lent ... ( Interruption : ) H. le président schneider . Arrivez donc à la ques
# rté de conscience ! Eu 18 * 9 , le président de la République voulait porter à
# ions sur plusieurs bancs . ) u. le président schneider . Si M. Guéroult veut êt
#  Je ne suis pas de l'avis de M. le président ; car , si les catholiques se cont
# expliquerai mes paroles , si M. le président la juge nécessaire . Mais je les c
# ais , vous n ' y étiez pas . m. le président schneider . Monsieur Gué roult , j
# aris . ( Interrup tion . ) bi . le président S chneider . Je prie M. Gué roult
# rmée ( Bruits divers . ) j si . le président S chneider . Je prie M. Tliiers de
# istre d'Etat . ( Bruit . ) si . IM président S chneider . Monsieur Pelle tan l
# cer cle dont M. de Camors est le ' président , dans lequel on jure de mépriser
#
# Concordance analysis for 'président' in Block 3:
# Displaying 25 of 197 matches:
#  remplie , par les nomi nations de président , des vice-prési dents , secrétair
# oix , M. Martel a été choisi comme président pour l'année 1880 . Ce pauvre M. J
# ciellement que M. Gambetta restera président de la Chambre . Mais on ajoute que
# claration ministé . rielle . M. le président du Conseil lui-même e£ fera la lec
# de M. Lepère a été acceptée par le Président de là République , bien qu'elle eû
# rsation . immédiatement après , le Président de la République est allé lui rend
# tatue du défenseur de Belfort . Le Président de la République s'est fait représ
# core aperçu clans cette tribune le Président de là '' Répu blique , qui a été r
#  ; en effet , que M. Cernes- son , président du Conseil municipal de dPai'is ,
# enkî M. Arles Dufour , M. Ballot , président de section au Conseil d'Etat , M.
# et présentera mardi ses lettres au président de la République . La princesse de
# se . ' Au début de la réunion , le président a vivement félicité , au nom de la
#  attaché à la maison ihilitairp du président de la République . \ M. Lichtenste
# onnable iians l'élection du -futur Président serait l'abstention complète , 5 c
# mpérial .d'Allema- gne.a envoyé au président von Wedell la dépêche suivante , /
# s son immense fortune . M. Béhic , président du Conseil d'ad- ministration des
# acre est à la porte , -monsieur le Président . '-.c^i , , , . . — Ne m , '' app
# , , , . . — Ne m , '' appelez plus président . I ) ans un instant , j'aùrâi ' q
#  est quatre'■ heures , monsieur le Président . ■— Ce n'est pas possible l. Vous
# e . - — C'est fait , monsieur le . Président .. ... -— Partons ... je-n'oublie
#  chose . —^ Mais non , monsieur le Président . - — Dans ce cas , , partons .. ;
#  partirons ensuite . — Monsieur le Président ... — Entrez , monsieur , et faite
# u moins se porteront sur le nom du président de la Chambre . Il : en faut compt
# ède avait fait proclamer Boulanger président d'honneur de là Ligue des Patriote
# le en vue d'un quitus à obtenir du président Grévy . Quittance obtenue en fraud
#
# Concordance analysis for 'président' in Block 4:
# Displaying 25 of 670 matches:
# te fixée au 15 avril prochain , le Président de la Ré publique et Mme Loubet do
#  L ' E cole des Expositions a pour président M. Léon Bourgeois , et pour secrét
# emier objet nette ment défini . Le président du groupe français est réminent vi
#  — J. Cornély . A Travers Paris Le Président de la République a reçu hier , à .
# ysée et il a été conduit auprès du Président de la République par M. Crozier ,
# reprises , Jes hautes fonctions do président du Conseilles ministres et de mini
# rieur . .. ■ M. Waldeck-Rousseau , président du Conseil , bien qu'il soit encor
#  et assistera à la revue à'côté du Président de la République . • Le cortège of
# e , chef de la maison militaire du Président de la République . Etait depuis 18
#  • , : 'Un vieil ami d'ailleurs du Président delà République '' , - qui lui don
# s profond et le plus émouvant , le président prit la parole en ces termes : : M
#  été communiquée dans la -soirée ; Président élu de la Chambre , j'avais un dev
# e prononcer la déchéance ! Puis le président Schneider proposa is nouveau âè -r
# re , le général comte de Palikao , président du Conseil , déposa un projet de l
# 'invi tation que lui a adressée le président du Conseil municipal de Paris . ;
# é. , de l 'ordre de Saint-André au Président de , là Répu blique a e , ù lieu .
# ici ce texte : A Monsieur Loubet , Président .de la République française. . , M
# ublique française. . , Monsieur le Président , très cher et grand ami , Les sen
# en agréer ïaeswance , Mon sieur le Président , très cher et grand ami , apec ce
# rince Ouroussoff , en remettant au Président de la République avec cette lettre
# 'allocution suivante : Monsieur le Président , S. M. l'Empereur a daigné me con
#  pour votre personne , monsieur le Président . En conférant la plus , haute dis
# jesté'auprès de vous , monsieur le Président . La mission dont je suis chargé a
#  entre la France et la Russie . Le Président de la République a ré pondu : Mons
# s donnant le mandat de remettre au Président de la République les insignes de l
